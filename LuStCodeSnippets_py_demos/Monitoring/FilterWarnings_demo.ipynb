# %%
#%%imports
import matplotlib.pyplot as plt

# %%
def raise_warnings():

    #matplotlib warnings
    fig, axs = plt.subplots(1,1)
    axs.set_xticklabels(range(10,20))
    plt.close()

    return

raise_warnings()
# Out:
# /tmp/ipykernel_19025/3500258534.py:4: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axs.set_xticklabels(range(10,20))

# %%
from LuStCodeSnippets_py.Monitoring import FilterWarnings

raise_warnings()
