# %%
from lust_codesnippets_py.styles import designing as alstde

# %% [markdown]
# ## Designing Colorscales

# %%
alstde.design_colorscale(
    colorscale=[ #TRE
        [0.0, "hsl(0,0%,95%)"],
        [0.3, "hsl(0,0%,75%)"],
        [0.8, "hsl(0,0%,30%)"],
        [0.9, "hsl(0,100%,22%)"],
        [1.0, "hsl(0,100%,15%)"],
    ],
    testfunc="gauss",
    normalize=True,
    noise=0.05,
    save="temp.png"
)
