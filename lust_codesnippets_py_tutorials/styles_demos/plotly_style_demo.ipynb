# %%
import importlib
import json
import numpy as np
import plotly.io as pio
import plotly.graph_objects as go
from plotly.subplots import make_subplots

from lust_codesnippets_py.styles import plotly_style as alstps

# %% [markdown]
# ## Custom Colormaps Have Been Registered

# %%
fig = make_subplots(rows=2, cols=2)
fig.add_trace(dict(z=np.linspace(np.zeros(100), 1, 100).T, type="heatmap", colorscale=alstps.fink_colorscale), row=1, col=1)
fig.add_trace(dict(z=np.linspace(np.zeros(100), 1, 100).T, type="heatmap", colorscale=alstps.tre_colorscale), row=2, col=1)
fig.add_trace(dict(z=np.linspace(np.zeros(100), 1, 100).T, type="heatmap", colorscale=alstps.tre_colorscale_light), row=2, col=2)
fig.show()

# %% [markdown]
# # Define a Plot for Testing

# %%
def style_testplot(colorway=None, ls=None, markers=None, cmap=None, hatches=None):
    """
        - function defining a testplot to compare different styles with each other
    """

    #load predefined plot from json
    with open("../../styles/demos/style_demo.json", "r") as f:
        data = json.load(f)

    data["layout"]["width"] = 900
    data["layout"]["height"] = 900
    fig = go.Figure(layout=data["layout"], data=data["traces"])
    fig.show()

    return

# %% [markdown]
# # Different Defined Styles

# %% [markdown]
# ### `tre("dark","cycle")`

# %%
importlib.reload(alstps)
colorway, ls, markers, cmap, hatches = alstps.tre("dark","cycle")
print(pio.templates)
style_testplot()
# Out:
# Templates configuration
# -----------------------
#     Default template: 'tre_dark_cycle'
#     Available templates:
#         ['ggplot2', 'seaborn', 'simple_white', 'plotly',
#          'plotly_white', 'plotly_dark', 'presentation', 'xgridoff',
#          'ygridoff', 'gridon', 'none', 'tre_dark_cycle']

# %% [markdown]
# ### `tre("light","batch")`

# %%
importlib.reload(alstps)
colorway, ls, markers, cmap, hatches = alstps.tre("light","batch")
print(pio.templates)
style_testplot()
# Out:
# Templates configuration
# -----------------------
#     Default template: 'tre_light_batch'
#     Available templates:
#         ['ggplot2', 'seaborn', 'simple_white', 'plotly',
#          'plotly_white', 'plotly_dark', 'presentation', 'xgridoff',
#          'ygridoff', 'gridon', 'none', 'tre_dark_cycle',
#          'tre_light_batch']

# %% [markdown]
# ## `lust("dark","batch")`

# %%
importlib.reload(alstps)
colorway, ls, markers, cmap, hatches = alstps.lust("dark","batch")
print(pio.templates)
style_testplot()
# Out:
# Templates configuration
# -----------------------
#     Default template: 'lust_dark_batch'
#     Available templates:
#         ['ggplot2', 'seaborn', 'simple_white', 'plotly',
#          'plotly_white', 'plotly_dark', 'presentation', 'xgridoff',
#          'ygridoff', 'gridon', 'none', 'tre_dark_cycle',
#          'tre_light_batch', 'lust_dark_batch']

# %% [markdown]
# ## `lust("light","cycle")`

# %%
importlib.reload(alstps)
colorway, ls, markers, cmap, hatches = alstps.lust("light","cycle")
print(pio.templates)
style_testplot()
# Out:
# Templates configuration
# -----------------------
#     Default template: 'lust_light_cycle'
#     Available templates:
#         ['ggplot2', 'seaborn', 'simple_white', 'plotly',
#          'plotly_white', 'plotly_dark', 'presentation', 'xgridoff',
#          'ygridoff', 'gridon', 'none', 'tre_dark_cycle',
#          'tre_light_batch', 'lust_dark_batch', 'lust_light_cycle']

# %% [markdown]
# ## `fink("dark","cycle")`

# %%
importlib.reload(alstps)
colorway, ls, markers, cmap, hatches = alstps.fink("dark","cycle")
print(pio.templates)
style_testplot()
# Out:
# Templates configuration
# -----------------------
#     Default template: 'fink_dark_cycle'
#     Available templates:
#         ['ggplot2', 'seaborn', 'simple_white', 'plotly',
#          'plotly_white', 'plotly_dark', 'presentation', 'xgridoff',
#          'ygridoff', 'gridon', 'none', 'tre_dark_cycle',
#          'tre_light_batch', 'lust_dark_batch', 'lust_light_cycle',
#          'fink_dark_cycle', 'fink_light_batch', 'tre_variation']

# %% [markdown]
# ## `fink("light","batch")`

# %%
importlib.reload(alstps)
colorway, ls, markers, cmap, hatches = alstps.fink("light","batch")
print(pio.templates)
style_testplot()
# Out:
# Templates configuration
# -----------------------
#     Default template: 'fink_light_batch'
#     Available templates:
#         ['ggplot2', 'seaborn', 'simple_white', 'plotly',
#          'plotly_white', 'plotly_dark', 'presentation', 'xgridoff',
#          'ygridoff', 'gridon', 'none', 'tre_dark_cycle',
#          'tre_light_batch', 'lust_dark_batch', 'lust_light_cycle',
#          'fink_dark_cycle', 'fink_light_batch']

# %% [markdown]
# # Quick Customizations

# %%
importlib.reload(alstps)
colorway, ls, markers, cmap, hatches = alstps.tre("dark","cycle", colorway_override=["#f49bf4","#eaff74","#91fecb","#82aef6"], cmap_override="rainbow", themename_override="tre_variation")
print(pio.templates)
style_testplot()
# Out:
# Templates configuration
# -----------------------
#     Default template: 'tre_variation'
#     Available templates:
#         ['ggplot2', 'seaborn', 'simple_white', 'plotly',
#          'plotly_white', 'plotly_dark', 'presentation', 'xgridoff',
#          'ygridoff', 'gridon', 'none', 'tre_dark_cycle',
#          'tre_light_batch', 'lust_dark_batch', 'lust_light_cycle',
#          'fink_dark_cycle', 'fink_light_batch', 'tre_variation']
